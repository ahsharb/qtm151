# %% [markdown]
# # QTM 151 - Quiz 2

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
Ahshar Brown

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:
"I will abide by Emory's code of conduct"

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", <br>
# "pandas", "statsmodels.api" and "statsmodels.formula.api"

# %%
# Write your answer here
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# <font size = "5">
#
# Read the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting <br>
# to get a sense of its content

# %%
# Write your own code
dataset = pd.read_csv("data_quiz/fifa23_players_basic.csv")
display(dataset)
# Out:
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 4               4       K. Mbappé       Kylian Mbappé       91         95
# ...           ...             ...                 ...      ...        ...
# 18534       18534      D. Collins      Darren Collins       47         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 3           107500000           CM,CAM            CM              Belgium
# 4           190500000            ST,LW            ST               France
# ...               ...              ...           ...                  ...
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  Preferred Foot  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...            Left
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...           Right
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...           Right
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...           Right
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...           Right
# ...                                                 ...  ...             ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png  ...           Right
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...           Right
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...           Right
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...           Right
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...            Left
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 0                     4            4                         5
# 1                     4            4                         4
# 2                     4            4                         5
# 3                     5            4                         4
# 4                     4            5                         4
# ...                 ...          ...                       ...
# 18534                 3            2                         1
# 18535                 3            2                         1
# 18536                 3            2                         1
# 18537                 3            2                         1
# 18538                 3            2                         1
#
#        National Team Name             National Team Image Link  \
# 0               Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium  https://cdn.sofifa.net/flags/be.png
# 4                  France  https://cdn.sofifa.net/flags/fr.png
# ...                   ...                                  ...
# 18534                   -                                    -
# 18535                   -                                    -
# 18536                   -                                    -
# 18537                   -                                    -
# 18538                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 0                          RW                           10
# 1                          ST                           19
# 2                          ST                            9
# 3                          RF                            7
# 4                          ST                           10
# ...                       ...                          ...
# 18534                       -                            -
# 18535                       -                            -
# 18536                       -                            -
# 18537                       -                            -
# 18538                       -                            -
#
#       Attacking Work Rate Defensive Work Rate
# 0                     Low                 Low
# 1                  Medium              Medium
# 2                    High              Medium
# 3                    High                High
# 4                    High                 Low
# ...                   ...                 ...
# 18534              Medium              Medium
# 18535              Medium              Medium
# 18536                High              Medium
# 18537              Medium              Medium
# 18538              Medium              Medium
#
# [18539 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (a) Use queries + global variables
#
# <font size = "3">
#
# - Subset the players whose value of the column "On Loan" is "YES" <br>
# and store it in a new dataset
# - How many players are on loan?
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# and when the value is a string. <br>
# Reference the column as ``` `On Loan` ``` inside .query()

# %%
# Write your own code
dataset["new variable"] = dataset["On Loan"]
data_spacesthreshold = dataset.query("`new variable` == 'YES' ")
display(data_spacesthreshold)

players_on_loan_count = data_spacesthreshold.shape[0]
print(f"Number of players on loan: {players_on_loan_count}")
# Out:
#        Unnamed: 0        Known As                   Full Name  Overall  \
# 45             45       R. Lukaku               Romelu Lukaku       86
# 154           154        Angeliño  José Ángel Esmoris Tasende       83
# 191           191    A. Griezmann           Antoine Griezmann       83
# 204           204    M. Locatelli            Manuel Locatelli       82
# 205           205       R. Gosens                Robin Gosens       82
# ...           ...             ...                         ...      ...
# 18206       18206  Kim Jeong hoon              Jeong Hoon Kim       52
# 18283       18283       E. Taylor                Ellis Taylor       51
# 18343       18343     Yoon Suk Ju                 Suk Ju Yoon       50
# 18390       18390     S. Ghidotti             Simone Ghidotti       50
# 18431       18431       D. Robson                David Robson       50
#
#        Potential  Value(in Euro) Positions Played Best Position  \
# 45            86        68000000               ST            ST
# 154           85        42000000           LWB,LM            LM
# 191           83        30500000         ST,CF,RW           CAM
# 204           86        40000000           CDM,CM            CM
# 205           82        29500000           LWB,LM           LWB
# ...          ...             ...              ...           ...
# 18206         62          160000               GK            GK
# 18283         65          140000            RM,LB            LM
# 18343         65          110000              CDM           CDM
# 18390         57           80000               GK            GK
# 18431         63          100000               GK            GK
#
#           Nationality                                        Image Link  ...  \
# 45            Belgium  https://cdn.sofifa.net/players/192/505/23_60.png  ...
# 154             Spain  https://cdn.sofifa.net/players/220/651/23_60.png  ...
# 191            France  https://cdn.sofifa.net/players/194/765/23_60.png  ...
# 204             Italy  https://cdn.sofifa.net/players/222/077/23_60.png  ...
# 205           Germany  https://cdn.sofifa.net/players/223/697/23_60.png  ...
# ...               ...                                               ...  ...
# 18206  Korea Republic  https://cdn.sofifa.net/players/252/662/23_60.png  ...
# 18283         England  https://cdn.sofifa.net/players/263/990/23_60.png  ...
# 18343  Korea Republic  https://cdn.sofifa.net/players/261/121/23_60.png  ...
# 18390           Italy  https://cdn.sofifa.net/players/270/756/23_60.png  ...
# 18431           Wales  https://cdn.sofifa.net/players/258/888/23_60.png  ...
#
#        National Team Name                 National Team Image Link  \
# 45                Belgium      https://cdn.sofifa.net/flags/be.png
# 154                     -      https://cdn.sofifa.net/flags/es.png
# 191                France      https://cdn.sofifa.net/flags/fr.png
# 204                 Italy      https://cdn.sofifa.net/flags/it.png
# 205               Germany      https://cdn.sofifa.net/flags/de.png
# ...                   ...                                      ...
# 18206                   -                                        -
# 18283                   -  https://cdn.sofifa.net/flags/gb-eng.png
# 18343                   -                                        -
# 18390                   -      https://cdn.sofifa.net/flags/it.png
# 18431                   -  https://cdn.sofifa.net/flags/gb-wls.png
#
#        National Team Position  National Team Jersey Number  \
# 45                         ST                            9
# 154                         -                            -
# 191                       CAM                            7
# 204                       SUB                            5
# 205                       SUB                           16
# ...                       ...                          ...
# 18206                       -                            -
# 18283                       -                            -
# 18343                       -                            -
# 18390                       -                            -
# 18431                       -                            -
#
#        Attacking Work Rate Defensive Work Rate  new variable  \
# 45                  Medium                 Low           YES
# 154                   High                High           YES
# 191                 Medium              Medium           YES
# 204                 Medium                High           YES
# 205                   High              Medium           YES
# ...                    ...                 ...           ...
# 18206               Medium              Medium           YES
# 18283               Medium              Medium           YES
# 18343               Medium              Medium           YES
# 18390               Medium              Medium           YES
# 18431               Medium              Medium           YES
#
#        player_classification p_estimated random_var
# 45         Non Top Performer   69.715462   0.340884
# 154        Non Top Performer   71.099875   0.597097
# 191        Non Top Performer   69.023256   0.851613
# 204        Non Top Performer   71.445978   0.287641
# 205        Non Top Performer   70.407669   0.591283
# ...                      ...         ...        ...
# 18206      Non Top Performer   72.484288   0.316160
# 18283      Non Top Performer   73.176494   0.614991
# 18343      Non Top Performer   72.830391   0.255105
# 18390      Non Top Performer   72.138184   0.198234
# 18431      Non Top Performer   72.830391   0.801719
#
# [1229 rows x 37 columns]
# Number of players on loan: 1229

# %% [markdown]
# <font size = "5">
#
# (b) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "Overall"
# - If "Overall > 90", classification = "Top Performer"
# - If "Overall <= 90", classification = "Non Top-Performer"
# - The function returns "classification"
#
# Step 2:
# - Extract the column "Overall" in the dataset <br>
# (be carefeful to write the "O" capitalized)
# - Create a new variable called "player_classification" <br>
# to assign each player to the correct classification
#
# HINT: Use the ".apply()" function

# %%
# Write your own code
Overall = 100
#Overall = 76 
def my_function(Overall): 
    if Overall > 90: 
        classification = "Top Performer"
        return classification 
    elif Overall <= 90: 
        classification = "Non Top Performer"
        return classification
result = my_function(Overall)

print(result)

column = dataset['Overall']
print(column)
dataset['player_classification'] = dataset['Overall'].apply(my_function)
print(dataset[['Overall', 'player_classification']])
# Out:
# Top Performer
# 0        91
# 1        91
# 2        91
# 3        91
# 4        91
#          ..
# 18534    47
# 18535    47
# 18536    47
# 18537    47
# 18538    47
# Name: Overall, Length: 18539, dtype: int64
#        Overall player_classification
# 0           91         Top Performer
# 1           91         Top Performer
# 2           91         Top Performer
# 3           91         Top Performer
# 4           91         Top Performer
# ...        ...                   ...
# 18534       47     Non Top Performer
# 18535       47     Non Top Performer
# 18536       47     Non Top Performer
# 18537       47     Non Top Performer
# 18538       47     Non Top Performer
#
# [18539 rows x 2 columns]

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# The varable "Joined On" shows the date in which each player joined FIFA
# - Use ".sort_values()" to order the "Joined On" column <br>
# from earlier data to later date
# - Get a subset with the 6 players in the dataset <br>
# who joined FIFA earliest
# - From this subset, display the year in which they joined <br>
# by displaying the column "Joined On"

# %%
# Write your own code
joined_On_Dates = dataset.sort_values(by = "Joined On", ascending = True)
display(joined_On_Dates)

earliest_6_players = joined_On_Dates.iloc[0:6, :]
display(earliest_6_players)

joined_years = earliest_6_players["Joined On"]
display(joined_years)
# Out:
#        Unnamed: 0         Known As                          Full Name  \
# 8586         8586     D. Lewington                     Dean Lewington
# 10877       10877      P. Karlsson                       Per Karlsson
# 4324         4324         I. Khune                    Itumeleng Khune
# 11056       11056      Cai Huikang                        Huikang Cai
# 10360       10360     L. Stevenson                    Lewis Stevenson
# ...           ...              ...                                ...
# 11623       11623        K. Tapoko                       Kevin Tapoko
# 3551         3551         P. Lasne                         Paul Lasne
# 11618       11618         V. Dican                       Victor Dican
# 3538         3538  Édundo Oliveira         Éder Marvin Oliveira Simão
# 3152         3152  João Bruinheira  João Fabrício Bruinheira Salvador
#
#        Overall  Potential  Value(in Euro) Positions Played Best Position  \
# 8586        66         66          150000               CB           CDM
# 10877       64         64          100000               CB            CB
# 4324        70         70          180000               GK            GK
# 11056       64         64          400000           CDM,CM            CB
# 10360       65         65          250000               LB            LB
# ...        ...        ...             ...              ...           ...
# 11623       64         65          575000           CDM,CM           CDM
# 3551        72         72         1200000           CDM,CM           CDM
# 11618       64         73         1200000           CB,CDM            CB
# 3538        72         72         1900000               CB            CB
# 3152        72         72          400000               GK            GK
#
#         Nationality                                        Image Link  ...  \
# 8586        England  https://cdn.sofifa.net/players/138/830/23_60.png  ...
# 10877        Sweden  https://cdn.sofifa.net/players/176/717/23_60.png  ...
# 4324   South Africa  https://cdn.sofifa.net/players/165/247/23_60.png  ...
# 11056      China PR  https://cdn.sofifa.net/players/224/608/23_60.png  ...
# 10360      Scotland  https://cdn.sofifa.net/players/175/316/23_60.png  ...
# ...             ...                                               ...  ...
# 11623        France  https://cdn.sofifa.net/players/211/484/23_60.png  ...
# 3551         France  https://cdn.sofifa.net/players/192/242/23_60.png  ...
# 11618       Romania  https://cdn.sofifa.net/players/266/792/23_60.png  ...
# 3538         Brazil  https://cdn.sofifa.net/players/230/389/23_60.png  ...
# 3152         Brazil  https://cdn.sofifa.net/players/230/525/23_60.png  ...
#
#        National Team Name                 National Team Image Link  \
# 8586                    -  https://cdn.sofifa.net/flags/gb-eng.png
# 10877                   -      https://cdn.sofifa.net/flags/se.png
# 4324                    -      https://cdn.sofifa.net/flags/za.png
# 11056                   -                                        -
# 10360                   -  https://cdn.sofifa.net/flags/gb-sct.png
# ...                   ...                                      ...
# 11623                   -      https://cdn.sofifa.net/flags/fr.png
# 3551                    -      https://cdn.sofifa.net/flags/fr.png
# 11618                   -      https://cdn.sofifa.net/flags/ro.png
# 3538                    -      https://cdn.sofifa.net/flags/br.png
# 3152                    -      https://cdn.sofifa.net/flags/br.png
#
#        National Team Position  National Team Jersey Number  \
# 8586                        -                            -
# 10877                       -                            -
# 4324                        -                            -
# 11056                       -                            -
# 10360                       -                            -
# ...                       ...                          ...
# 11623                       -                            -
# 3551                        -                            -
# 11618                       -                            -
# 3538                        -                            -
# 3152                        -                            -
#
#        Attacking Work Rate Defensive Work Rate  new variable  \
# 8586                  High              Medium             -
# 10877                  Low                High             -
# 4324                Medium              Medium             -
# 11056                  Low                High             -
# 10360                 High                High             -
# ...                    ...                 ...           ...
# 11623               Medium              Medium             -
# 3551                Medium                High             -
# 11618               Medium              Medium             -
# 3538                Medium              Medium             -
# 3152                Medium              Medium             -
#
#        player_classification p_estimated random_var
# 8586       Non Top Performer   66.600534   0.673697
# 10877      Non Top Performer   67.292740   0.580627
# 4324       Non Top Performer   67.638843   0.026812
# 11056      Non Top Performer   68.677153   0.166264
# 10360      Non Top Performer   67.984947   0.660085
# ...                      ...         ...        ...
# 11623      Non Top Performer   70.061565   0.051990
# 3551       Non Top Performer   68.331050   0.951984
# 11618      Non Top Performer   72.484288   0.174475
# 3538       Non Top Performer   69.369359   0.363220
# 3152       Non Top Performer   67.984947   0.831718
#
# [18539 rows x 37 columns]
#        Unnamed: 0       Known As        Full Name  Overall  Potential  \
# 8586         8586   D. Lewington   Dean Lewington       66         66
# 10877       10877    P. Karlsson     Per Karlsson       64         64
# 4324         4324       I. Khune  Itumeleng Khune       70         70
# 11056       11056    Cai Huikang      Huikang Cai       64         64
# 10360       10360   L. Stevenson  Lewis Stevenson       65         65
# 11768       11768  Wang Shenchao    Shenchao Wang       64         64
#
#        Value(in Euro) Positions Played Best Position   Nationality  \
# 8586           150000               CB           CDM       England
# 10877          100000               CB            CB        Sweden
# 4324           180000               GK            GK  South Africa
# 11056          400000           CDM,CM            CB      China PR
# 10360          250000               LB            LB      Scotland
# 11768          275000            CB,RM            CB      China PR
#
#                                              Image Link  ...  \
# 8586   https://cdn.sofifa.net/players/138/830/23_60.png  ...
# 10877  https://cdn.sofifa.net/players/176/717/23_60.png  ...
# 4324   https://cdn.sofifa.net/players/165/247/23_60.png  ...
# 11056  https://cdn.sofifa.net/players/224/608/23_60.png  ...
# 10360  https://cdn.sofifa.net/players/175/316/23_60.png  ...
# 11768  https://cdn.sofifa.net/players/224/604/23_60.png  ...
#
#        National Team Name                 National Team Image Link  \
# 8586                    -  https://cdn.sofifa.net/flags/gb-eng.png
# 10877                   -      https://cdn.sofifa.net/flags/se.png
# 4324                    -      https://cdn.sofifa.net/flags/za.png
# 11056                   -                                        -
# 10360                   -  https://cdn.sofifa.net/flags/gb-sct.png
# 11768            China PR                                        -
#
#        National Team Position  National Team Jersey Number  \
# 8586                        -                            -
# 10877                       -                            -
# 4324                        -                            -
# 11056                       -                            -
# 10360                       -                            -
# 11768                      RB                            4
#
#        Attacking Work Rate Defensive Work Rate  new variable  \
# 8586                  High              Medium             -
# 10877                  Low                High             -
# 4324                Medium              Medium             -
# 11056                  Low                High             -
# 10360                 High                High             -
# 11768                 High                High             -
#
#        player_classification p_estimated random_var
# 8586       Non Top Performer   66.600534   0.673697
# 10877      Non Top Performer   67.292740   0.580627
# 4324       Non Top Performer   67.638843   0.026812
# 11056      Non Top Performer   68.677153   0.166264
# 10360      Non Top Performer   67.984947   0.660085
# 11768      Non Top Performer   68.331050   0.939978
#
# [6 rows x 37 columns]
# 8586     2002
# 10877    2003
# 4324     2004
# 11056    2005
# 10360    2005
# 11768    2005
# Name: Joined On, dtype: int64

# %% [markdown]
# <font size = "5">
#
# (d) Regression function
#
# <font size = "3">
#
# - Run a regression of "Potential" (left-hand side) on "Age" (right-hand side)
# - What are the values of the coefficients?
#
# [HINT: Use the commands ```smf.ols()``` and ```.fit()``` and ```.params``` <br>
# from Lecture 11 ]

# %%
# Write your own code
model = smf.ols(formula='Potential ~ Age', data=dataset)
results = model.fit()

b_list = results.params
print("Intercept:", b_list[0])
print("Coefficient (Slope):", b_list[1])

dataset["p_estimated"] = b_list[0] + b_list[1] * dataset["Age"]

plt.scatter(x=dataset["Age"], y=dataset["Potential"], label="Data points")
plt.plot(dataset["Age"], dataset["p_estimated"], color='red', label="Estimated Predicted Model")
plt.xlabel('Age')
plt.ylabel('Potential')
plt.legend()
plt.show()
# Out:
# /var/folders/25/qxcs16453qb54fdqn6_myjcc0000gn/T/ipykernel_90327/1235699846.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("Intercept:", b_list[0])
# /var/folders/25/qxcs16453qb54fdqn6_myjcc0000gn/T/ipykernel_90327/1235699846.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("Coefficient (Slope):", b_list[1])
# /var/folders/25/qxcs16453qb54fdqn6_myjcc0000gn/T/ipykernel_90327/1235699846.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dataset["p_estimated"] = b_list[0] + b_list[1] * dataset["Age"]
# Intercept: 79.7524538648746
# Coefficient (Slope): -0.3461031564434816

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Store the total number of rows of the dataset in a variable called ```n``` <br>
# - Create a new variable called ```random_var``` drawn from a <br>
# uniform distribution between 0 and 1 with size ```n```
# - Use .query() to subset all observations with ```random_var <0.5```.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with ```random_var >= 0.5```.<br>
# store it in a new dataset called "data1"
#
# [HINT: See Lecture 2 for how to generate a uniform random variable]

# %%
# Write your own code
n = len(dataset)

dataset['random_var'] = np.random.uniform(0, 1, size=n)
data0 = dataset.query('random_var < 0.5')
data1 = dataset.query('random_var >= 0.5')

print("random_var < 0.5 (data0):")
print(data0)
display(data0)

print("random_var >= 0.5 (data1):")
print(data1)
display(data1)
# Out:
# random_var < 0.5 (data0):
#        Unnamed: 0           Known As                     Full Name  Overall  \
# 3               3       K. De Bruyne               Kevin De Bruyne       91
# 4               4          K. Mbappé                 Kylian Mbappé       91
# 5               5           M. Salah                 Mohamed Salah       90
# 8               8  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro       90
# 9               9        V. van Dijk               Virgil van Dijk       90
# ...           ...                ...                           ...      ...
# 18527       18527        Liu Junxian                   Junxian Liu       48
# 18530       18530             S. Bag                     Sajal Bag       48
# 18531       18531           Liao Wei                      Wei Liao       48
# 18533       18533          Pi Ziyang                     Ziyang Pi       47
# 18534       18534         D. Collins                Darren Collins       47
#
#        Potential  Value(in Euro) Positions Played Best Position  \
# 3             91       107500000           CM,CAM            CM
# 4             95       190500000            ST,LW            ST
# 5             90       115500000               RW            RW
# 8             90        41000000               ST            ST
# 9             90        98000000               CB            CB
# ...          ...             ...              ...           ...
# 18527         58          110000               ST            ST
# 18530         61          110000            CM,RM            RM
# 18531         54           70000            RM,LM           CDM
# 18533         60          110000               CM           CAM
# 18534         56          110000            ST,RM           CAM
#
#                Nationality                                        Image Link  \
# 3                  Belgium  https://cdn.sofifa.net/players/192/985/23_60.png
# 4                   France  https://cdn.sofifa.net/players/231/747/23_60.png
# 5                    Egypt  https://cdn.sofifa.net/players/209/331/23_60.png
# 8                 Portugal  https://cdn.sofifa.net/players/020/801/23_60.png
# 9              Netherlands  https://cdn.sofifa.net/players/203/376/23_60.png
# ...                    ...                                               ...
# 18527             China PR  https://cdn.sofifa.net/players/264/056/23_60.png
# 18530                India  https://cdn.sofifa.net/players/270/739/23_60.png
# 18531             China PR  https://cdn.sofifa.net/players/257/691/23_60.png
# 18533             China PR  https://cdn.sofifa.net/players/269/066/23_60.png
# 18534  Republic of Ireland  https://cdn.sofifa.net/players/243/725/23_60.png
#
#        ...  National Team Name             National Team Image Link  \
# 3      ...             Belgium  https://cdn.sofifa.net/flags/be.png
# 4      ...              France  https://cdn.sofifa.net/flags/fr.png
# 5      ...                   -                                    -
# 8      ...            Portugal  https://cdn.sofifa.net/flags/pt.png
# 9      ...         Netherlands  https://cdn.sofifa.net/flags/nl.png
# ...    ...                 ...                                  ...
# 18527  ...                   -                                    -
# 18530  ...                   -                                    -
# 18531  ...                   -                                    -
# 18533  ...                   -                                    -
# 18534  ...                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 3                          RF                            7
# 4                          ST                           10
# 5                           -                            -
# 8                          ST                            7
# 9                          CB                            4
# ...                       ...                          ...
# 18527                       -                            -
# 18530                       -                            -
# 18531                       -                            -
# 18533                       -                            -
# 18534                       -                            -
#
#        Attacking Work Rate Defensive Work Rate  new variable  \
# 3                     High                High             -
# 4                     High                 Low             -
# 5                     High              Medium             -
# 8                     High                 Low             -
# 9                   Medium                High             -
# ...                    ...                 ...           ...
# 18527               Medium              Medium             -
# 18530               Medium              Medium             -
# 18531               Medium              Medium             -
# 18533               Medium              Medium             -
# 18534               Medium              Medium             -
#
#        player_classification p_estimated random_var
# 3              Top Performer   69.023256   0.414900
# 4              Top Performer   71.792081   0.423852
# 5          Non Top Performer   69.369359   0.001770
# 8          Non Top Performer   66.946637   0.167894
# 9          Non Top Performer   69.369359   0.032409
# ...                      ...         ...        ...
# 18527      Non Top Performer   72.484288   0.182556
# 18530      Non Top Performer   73.176494   0.022498
# 18531      Non Top Performer   71.792081   0.238783
# 18533      Non Top Performer   73.176494   0.088824
# 18534      Non Top Performer   72.484288   0.114627
#
# [9273 rows x 37 columns]
#        Unnamed: 0           Known As                     Full Name  Overall  \
# 3               3       K. De Bruyne               Kevin De Bruyne       91
# 4               4          K. Mbappé                 Kylian Mbappé       91
# 5               5           M. Salah                 Mohamed Salah       90
# 8               8  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro       90
# 9               9        V. van Dijk               Virgil van Dijk       90
# ...           ...                ...                           ...      ...
# 18527       18527        Liu Junxian                   Junxian Liu       48
# 18530       18530             S. Bag                     Sajal Bag       48
# 18531       18531           Liao Wei                      Wei Liao       48
# 18533       18533          Pi Ziyang                     Ziyang Pi       47
# 18534       18534         D. Collins                Darren Collins       47
#
#        Potential  Value(in Euro) Positions Played Best Position  \
# 3             91       107500000           CM,CAM            CM
# 4             95       190500000            ST,LW            ST
# 5             90       115500000               RW            RW
# 8             90        41000000               ST            ST
# 9             90        98000000               CB            CB
# ...          ...             ...              ...           ...
# 18527         58          110000               ST            ST
# 18530         61          110000            CM,RM            RM
# 18531         54           70000            RM,LM           CDM
# 18533         60          110000               CM           CAM
# 18534         56          110000            ST,RM           CAM
#
#                Nationality                                        Image Link  \
# 3                  Belgium  https://cdn.sofifa.net/players/192/985/23_60.png
# 4                   France  https://cdn.sofifa.net/players/231/747/23_60.png
# 5                    Egypt  https://cdn.sofifa.net/players/209/331/23_60.png
# 8                 Portugal  https://cdn.sofifa.net/players/020/801/23_60.png
# 9              Netherlands  https://cdn.sofifa.net/players/203/376/23_60.png
# ...                    ...                                               ...
# 18527             China PR  https://cdn.sofifa.net/players/264/056/23_60.png
# 18530                India  https://cdn.sofifa.net/players/270/739/23_60.png
# 18531             China PR  https://cdn.sofifa.net/players/257/691/23_60.png
# 18533             China PR  https://cdn.sofifa.net/players/269/066/23_60.png
# 18534  Republic of Ireland  https://cdn.sofifa.net/players/243/725/23_60.png
#
#        ...  National Team Name             National Team Image Link  \
# 3      ...             Belgium  https://cdn.sofifa.net/flags/be.png
# 4      ...              France  https://cdn.sofifa.net/flags/fr.png
# 5      ...                   -                                    -
# 8      ...            Portugal  https://cdn.sofifa.net/flags/pt.png
# 9      ...         Netherlands  https://cdn.sofifa.net/flags/nl.png
# ...    ...                 ...                                  ...
# 18527  ...                   -                                    -
# 18530  ...                   -                                    -
# 18531  ...                   -                                    -
# 18533  ...                   -                                    -
# 18534  ...                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 3                          RF                            7
# 4                          ST                           10
# 5                           -                            -
# 8                          ST                            7
# 9                          CB                            4
# ...                       ...                          ...
# 18527                       -                            -
# 18530                       -                            -
# 18531                       -                            -
# 18533                       -                            -
# 18534                       -                            -
#
#        Attacking Work Rate Defensive Work Rate  new variable  \
# 3                     High                High             -
# 4                     High                 Low             -
# 5                     High              Medium             -
# 8                     High                 Low             -
# 9                   Medium                High             -
# ...                    ...                 ...           ...
# 18527               Medium              Medium             -
# 18530               Medium              Medium             -
# 18531               Medium              Medium             -
# 18533               Medium              Medium             -
# 18534               Medium              Medium             -
#
#        player_classification p_estimated random_var
# 3              Top Performer   69.023256   0.414900
# 4              Top Performer   71.792081   0.423852
# 5          Non Top Performer   69.369359   0.001770
# 8          Non Top Performer   66.946637   0.167894
# 9          Non Top Performer   69.369359   0.032409
# ...                      ...         ...        ...
# 18527      Non Top Performer   72.484288   0.182556
# 18530      Non Top Performer   73.176494   0.022498
# 18531      Non Top Performer   71.792081   0.238783
# 18533      Non Top Performer   73.176494   0.088824
# 18534      Non Top Performer   72.484288   0.114627
#
# [9273 rows x 37 columns]
# random_var >= 0.5 (data1):
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 6               6     T. Courtois    Thibaut Courtois       90         91
# 7               7        M. Neuer        Manuel Neuer       90         90
# ...           ...             ...                 ...      ...        ...
# 18532       18532        H. Singh   Harmanpreet Singh       48         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 6            90000000               GK            GK              Belgium
# 7            13500000               GK            GK              Germany
# ...               ...              ...           ...                  ...
# 18532          100000               ST            ST                India
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...
# 6      https://cdn.sofifa.net/players/192/119/23_60.png  ...
# 7      https://cdn.sofifa.net/players/167/495/23_60.png  ...
# ...                                                 ...  ...
# 18532  https://cdn.sofifa.net/players/259/745/23_60.png  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...
#
#        National Team Name             National Team Image Link  \
# 0               Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 6                 Belgium  https://cdn.sofifa.net/flags/be.png
# 7                 Germany  https://cdn.sofifa.net/flags/de.png
# ...                   ...                                  ...
# 18532                   -                                    -
# 18535                   -                                    -
# 18536                   -                                    -
# 18537                   -                                    -
# 18538                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 0                          RW                           10
# 1                          ST                           19
# 2                          ST                            9
# 6                          GK                            1
# 7                          GK                            1
# ...                       ...                          ...
# 18532                       -                            -
# 18535                       -                            -
# 18536                       -                            -
# 18537                       -                            -
# 18538                       -                            -
#
#        Attacking Work Rate Defensive Work Rate  new variable  \
# 0                      Low                 Low             -
# 1                   Medium              Medium             -
# 2                     High              Medium             -
# 6                   Medium              Medium             -
# 7                   Medium              Medium             -
# ...                    ...                 ...           ...
# 18532               Medium                 Low             -
# 18535               Medium              Medium             -
# 18536                 High              Medium             -
# 18537               Medium              Medium             -
# 18538               Medium              Medium             -
#
#        player_classification p_estimated random_var
# 0              Top Performer   67.638843   0.703525
# 1              Top Performer   67.984947   0.870310
# 2              Top Performer   68.331050   0.958446
# 6          Non Top Performer   69.369359   0.547412
# 7          Non Top Performer   67.292740   0.682112
# ...                      ...         ...        ...
# 18532      Non Top Performer   72.830391   0.763763
# 18535      Non Top Performer   73.868700   0.771523
# 18536      Non Top Performer   73.522597   0.530123
# 18537      Non Top Performer   73.868700   0.825122
# 18538      Non Top Performer   71.099875   0.891031
#
# [9266 rows x 37 columns]
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 6               6     T. Courtois    Thibaut Courtois       90         91
# 7               7        M. Neuer        Manuel Neuer       90         90
# ...           ...             ...                 ...      ...        ...
# 18532       18532        H. Singh   Harmanpreet Singh       48         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 6            90000000               GK            GK              Belgium
# 7            13500000               GK            GK              Germany
# ...               ...              ...           ...                  ...
# 18532          100000               ST            ST                India
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...
# 6      https://cdn.sofifa.net/players/192/119/23_60.png  ...
# 7      https://cdn.sofifa.net/players/167/495/23_60.png  ...
# ...                                                 ...  ...
# 18532  https://cdn.sofifa.net/players/259/745/23_60.png  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...
#
#        National Team Name             National Team Image Link  \
# 0               Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 6                 Belgium  https://cdn.sofifa.net/flags/be.png
# 7                 Germany  https://cdn.sofifa.net/flags/de.png
# ...                   ...                                  ...
# 18532                   -                                    -
# 18535                   -                                    -
# 18536                   -                                    -
# 18537                   -                                    -
# 18538                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 0                          RW                           10
# 1                          ST                           19
# 2                          ST                            9
# 6                          GK                            1
# 7                          GK                            1
# ...                       ...                          ...
# 18532                       -                            -
# 18535                       -                            -
# 18536                       -                            -
# 18537                       -                            -
# 18538                       -                            -
#
#        Attacking Work Rate Defensive Work Rate  new variable  \
# 0                      Low                 Low             -
# 1                   Medium              Medium             -
# 2                     High              Medium             -
# 6                   Medium              Medium             -
# 7                   Medium              Medium             -
# ...                    ...                 ...           ...
# 18532               Medium                 Low             -
# 18535               Medium              Medium             -
# 18536                 High              Medium             -
# 18537               Medium              Medium             -
# 18538               Medium              Medium             -
#
#        player_classification p_estimated random_var
# 0              Top Performer   67.638843   0.703525
# 1              Top Performer   67.984947   0.870310
# 2              Top Performer   68.331050   0.958446
# 6          Non Top Performer   69.369359   0.547412
# 7          Non Top Performer   67.292740   0.682112
# ...                      ...         ...        ...
# 18532      Non Top Performer   72.830391   0.763763
# 18535      Non Top Performer   73.868700   0.771523
# 18536      Non Top Performer   73.522597   0.530123
# 18537      Non Top Performer   73.868700   0.825122
# 18538      Non Top Performer   71.099875   0.891031
#
# [9266 rows x 37 columns]

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# <font size = "3">
#
# - This question requires the two datasets you created in (e)
# - Display the distribution of "Age" for "data0" and "data1" using <br>
# ```plt.hist()```
# - You will need to label the axes, and the title
# - To get full points, plot the histograms with the option  ```alpha = 0.5```, e.g. <br>
#  ``` plt.hist(x = ..., alpha = 0.5) ``` <br>
#  Make sure to substitute the corresponding "x" vector instead of ```...``` <br>
# (The alpha option sets the transparency of the histogram )
#
# Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups

# %%
# Write your own code
plt.hist(x=data0["Age"], alpha=0.5, label='Data0 (random_var < 0.5)')
plt.hist(x=data1["Age"], alpha=0.5, label='Data1 (random_var >= 0.5)')

plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Overlapping Histogram of Age for Data0 and Data1')
plt.legend(title="Random Var Groups")
plt.show()
